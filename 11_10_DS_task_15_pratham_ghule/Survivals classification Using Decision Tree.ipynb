# %%
#importing libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
#reading csv file
df=pd.read_csv("survivals.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    object
#  3   sex           850 non-null    object
#  4   age           676 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    object
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    object
#  10  embarked      849 non-null    object
#  11  boat          308 non-null    object
#  12  body          73 non-null     float64
#  13  home.dest     464 non-null    object
#  14  survived      850 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 99.7+ KB

# %%
df
# Out:
#      passenger_id  pclass                                               name  \
# 0            1216       3                                 Smyth, Miss. Julia
# 1             699       3                                    Cacic, Mr. Luka
# 2            1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3             449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4             576       2                                    Veal, Mr. James
# ..            ...     ...                                                ...
# 845           158       1                        Hipkins, Mr. William Edward
# 846           174       1                            Kent, Mr. Edward Austin
# 847           467       2                Kantor, Mrs. Sinai (Miriam Sternin)
# 848          1112       3                          Peacock, Miss. Treasteall
# 849           425       2                              Greenberg, Mr. Samuel
#
# ...

# %%
df["boat"].unique()
# Out:
# array(['13', nan, '4', '10', 'C', '8', '7', '16', '6', 'A', '15', '9',
#        '14', '3', '11', '12', '2', '5 7', '5 9', 'B', '5', 'D', '1',
#        'C D', '13 15', '13 15 B', '15 16'], dtype=object)

# %%
df["embarked"].unique()
# Out:
# array(['Q', 'S', 'C', nan], dtype=object)

# %%
df["pclass"].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
df["cabin"].unique()
# Out:
# array([nan, 'C82', 'D15', 'C50', 'E33', 'B57 B59 B63 B66', 'E34', 'C83',
#        'C125', 'B82 B84', 'B96 B98', 'B51 B53 B55', 'C132', 'C31', 'C68',
#        'B94', 'F E46', 'C126', 'D34', 'B28', 'C65', 'B52 B54 B56', 'D17',
#        'C86', 'C7', 'E25', 'E17', 'D56', 'A9', 'B26', 'C91', 'B5', 'D',
#        'A23', 'C22 C26', 'C124', 'E63', 'B35', 'B18', 'C6', 'B49', 'B19',
#        'G6', 'D35', 'C23 C25 C27', 'C62 C64', 'B73', 'E12', 'B41', 'A20',
#        'B69', 'C78', 'A14', 'D26', 'C51', 'B79', 'E52', 'C49', 'C104',
#        'B61', 'D43', 'D48', 'C123', 'A7', 'D47', 'D49', 'B80', 'A29',
#        'F38', 'B58 B60', 'A34', 'D33', 'D20', 'F G63', 'T', 'A6',
#        'C55 C57', 'B38', 'E49', 'F4', 'E121', 'C85', 'C87', 'B86', 'B102',
#        'C111', 'D22', 'B22', 'B77', 'B50', 'B30', 'E36', 'F33', 'E60',
#        'B39', 'C118', 'D21', 'F2', 'E39 E41', 'E101', 'A32', 'D38',
#        'C101', 'C54', 'C106', 'C32', 'D36', 'E50', 'D40', 'C30', 'C52',
# ...

# %%
df["ticket"].unique()
# Out:
# array(['335432', '315089', '345773', '29105', '28221', 'C 4001', 'LINE',
#        '250648', '347085', '4137', '113503', '11813', '11767',
#        'C.A. 2673', '350047', '239059', '367226', '113505', '347079',
#        '315098', '330877', '220845', '349250', 'A/4 31416', '244358',
#        '9232', '11668', '2686', '113789', 'PC 17318', 'S.P. 3464',
#        '383162', '28134', 'STON/O2. 3101270', 'PC 17608', 'S.O./P.P. 251',
#        '2926', 'SOTON/O.Q. 3101262', 'C.A. 6212', '16966', '113804',
#        '36973', '363294', 'SC/A.3 2861', 'CA. 2343', 'A/5 21171',
#        '244346', '26360', '2700', 'PC 17582', '365235',
#        'STON/O 2. 3101273', '349216', '14973', 'PC 17593', 'F.C.C. 13531',
#        '113760', 'PC 17755', '29104', '4133', 'A/5 3540', '368364',
#        'C.A. 2315', '7545', '13695', '27849', '248723', '343275',
#        'C.A. 5547', '363291', '349202', 'STON/O 2. 3101285', '7534',
#        '350026', 'PC 17761', '17475', '2680', '349209', '349228',
# ...

# %%
df.drop(labels = {'passenger_id' , 'name' ,'boat' , 'home.dest','cabin','ticket','body'} , axis = 1 , inplace = True)

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked  survived
# 0         3  female   NaN      0      0   7.7333        Q         1
# 1         3    male  38.0      0      0   8.6625        S         0
# 2         3  female  30.0      1      1  24.1500        S         0
# 3         2  female  54.0      1      3  23.0000        S         1
# 4         2    male  40.0      0      0  13.0000        S         0
# ..      ...     ...   ...    ...    ...      ...      ...       ...
# 845       1    male  55.0      0      0  50.0000        S         0
# 846       1    male  58.0      0      0  29.7000        C         0
# 847       2  female  24.0      1      0  26.0000        S         1
# 848       3  female   3.0      1      1  13.7750        S         0
# 849       2    male  52.0      0      0  13.0000        S         0
#
# [850 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# pclass        0
# sex           0
# age         174
# sibsp         0
# parch         0
# fare          1
# embarked      1
# survived      0
# dtype: int64

# %%
# drops all the rows containing null values from the dataframe 
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# survived    0
# dtype: int64

# %%
df.shape
# Out:
# (674, 8)

# %%
label_enc=LabelEncoder()
df["sex"]=label_enc.fit_transform(df["sex"])
df["embarked"]=label_enc.fit_transform(df["embarked"])

# %%
df
# Out:
#      pclass  sex   age  sibsp  parch     fare  embarked  survived
# 1         3    1  38.0      0      0   8.6625         2         0
# 2         3    0  30.0      1      1  24.1500         2         0
# 3         2    0  54.0      1      3  23.0000         2         1
# 4         2    1  40.0      0      0  13.0000         2         0
# 5         3    1  28.0      0      0  22.5250         2         0
# ..      ...  ...   ...    ...    ...      ...       ...       ...
# 845       1    1  55.0      0      0  50.0000         2         0
# 846       1    1  58.0      0      0  29.7000         0         0
# 847       2    0  24.0      1      0  26.0000         2         1
# 848       3    0   3.0      1      1  13.7750         2         0
# 849       2    1  52.0      0      0  13.0000         2         0
#
# [674 rows x 8 columns]

# %%
df.corr()
# Out:
#             pclass       sex       age     sibsp     parch      fare  \
# pclass    1.000000  0.182968 -0.410071  0.060117 -0.030252 -0.577234
# sex       0.182968  1.000000  0.033320 -0.111513 -0.168217 -0.193386
# age      -0.410071  0.033320  1.000000 -0.250097 -0.157844  0.194107
# sibsp     0.060117 -0.111513 -0.250097  1.000000  0.404454  0.113313
# parch    -0.030252 -0.168217 -0.157844  0.404454  1.000000  0.250807
# fare     -0.577234 -0.193386  0.194107  0.113313  0.250807  1.000000
# embarked  0.304271  0.110609 -0.087696  0.057560  0.021249 -0.326987
# survived -0.357697 -0.509433 -0.041436 -0.021496  0.112725  0.267222
#
#           embarked  survived
# pclass    0.304271 -0.357697
# sex       0.110609 -0.509433
# age      -0.087696 -0.041436
# sibsp     0.057560 -0.021496
# parch     0.021249  0.112725
# fare     -0.326987  0.267222
# embarked  1.000000 -0.189847
# survived -0.189847  1.000000

# %%
# x table is independant variables and y is target
y = df[["survived"]]
x = df.drop(["survived"],axis=1)

# %%
#making training and testing frames
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30,shuffle="true")

# %%
#fitting Decision Tree Classifier on training dataset
model = DecisionTreeClassifier().fit(x_train,y_train)

# %%
#predicting outcome
y_pred = model.predict(x_test)

# %%
#Finding accuracy of model
accuracy_score(y_test,y_pred)
# Out:
# 0.7586206896551724
